# %%
import numpy as np
import pandas as pd

# %%
# load data
country = pd.read_csv("/content/drive/MyDrive/Data Analytics Internship/Project Datasets/Week 4 - World Bank Data/Metadata_Country.csv")
population = pd.read_csv("/content/drive/MyDrive/Data Analytics Internship/Project Datasets/Week 4 - World Bank Data/country_population.csv")
fertility = pd.read_csv("/content/drive/MyDrive/Data Analytics Internship/Project Datasets/Week 4 - World Bank Data/fertility_rate.csv")
life_expectency = pd.read_csv("/content/drive/MyDrive/Data Analytics Internship/Project Datasets/Week 4 - World Bank Data/life_expectancy.csv")

# %%
country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN

# %%
country = country[['Country Code','Region']]

# %%
country.head()
# Out:
#   Country Code                     Region
# 0          ABW  Latin America & Caribbean
# 1          AFG                 South Asia
# 2          AGO         Sub-Saharan Africa
# 3          ALB      Europe & Central Asia
# 4          AND      Europe & Central Asia

# %%
country.isna().sum()
# Out:
# Country Code     0
# Region          46
# dtype: int64

# %%
country.shape
# Out:
# (263, 2)

# %%
country.isna().sum()
# Out:
# Country Code     0
# Region          46
# dtype: int64

# %%
population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2007  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101220.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  26616792.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  20997687.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2970017.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
population.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              4
#                  ..
# 2012              2
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# Length: 61, dtype: int64

# %%
population.drop(['Country Name','Indicator Name','Indicator Code'],axis =1,inplace=True)
population.head()
# Out:
#   Country Code       1960       1961       1962       1963       1964  \
# 0          ABW    54211.0    55438.0    56225.0    56695.0    57032.0
# 1          AFG  8996351.0  9166764.0  9345868.0  9533954.0  9731361.0
# 2          AGO  5643182.0  5753024.0  5866061.0  5980417.0  6093321.0
# 3          ALB  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0
# 4          AND    13411.0    14375.0    15370.0    16412.0    17469.0
#
#         1965        1966        1967        1968  ...        2007        2008  \
# 0    57360.0     57715.0     58055.0     58386.0  ...    101220.0    101353.0
# 1  9938414.0  10152331.0  10372630.0  10604346.0  ...  26616792.0  27294031.0
# 2  6203299.0   6309770.0   6414995.0   6523791.0  ...  20997687.0  21759420.0
# 3  1864791.0   1914573.0   1965598.0   2022272.0  ...   2970017.0   2947314.0
# 4    18549.0     19647.0     20758.0     21890.0  ...     82683.0     83861.0
#
# ...

# %%
population.columns
# Out:
# Index(['Country Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
population.shape
# Out:
# (264, 58)

# %%
population.dropna(axis =0,inplace=True)

# %%
population.shape
# Out:
# (258, 58)

# %% [markdown]
# Country Code    Year     Population
#
# ABW             1960     54211.0
#
# ---
#
#
#
# ---
#
#
# ABW             1961     55438.0

# %%
258 * 57
# Out:
# 14706

# %%
years = [str(i) for i in range(1960,2017)]
print(years)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']

# %%
# melt - unpivot the dataset

df = pd.melt(population,
        id_vars='Country Code',
        value_vars=years,
        var_name='Year',
        value_name='Polulation')

# %%
df.shape
# Out:
# (14706, 3)

# %%
df.head()
# Out:
#   Country Code  Year  Polulation
# 0          ABW  1960     54211.0
# 1          AFG  1960   8996351.0
# 2          AGO  1960   5643182.0
# 3          ALB  1960   1608800.0
# 4          AND  1960     13411.0

# %%
df.tail()
# Out:
#       Country Code  Year  Polulation
# 14701          XKX  2016   1816200.0
# 14702          YEM  2016  27584213.0
# 14703          ZAF  2016  56015473.0
# 14704          ZMB  2016  16591390.0
# 14705          ZWE  2016  16150362.0

# %%
country.head()
# Out:
#   Country Code                     Region
# 0          ABW  Latin America & Caribbean
# 1          AFG                 South Asia
# 2          AGO         Sub-Saharan Africa
# 3          ALB      Europe & Central Asia
# 4          AND      Europe & Central Asia

# %%
country.shape
# Out:
# (263, 2)

# %%
df.shape
# Out:
# (14706, 3)

# %%
df.head()
# Out:
#   Country Code  Year  Polulation
# 0          ABW  1960     54211.0
# 1          AFG  1960   8996351.0
# 2          AGO  1960   5643182.0
# 3          ALB  1960   1608800.0
# 4          AND  1960     13411.0

# %% [markdown]
# Country Code Region Year Population Fertility expet.

# %%
# merge
contry_and_population_merge = pd.merge(country,df,how='left',on='Country Code')

# %%
contry_and_population_merge.shape
# Out:
# (14711, 4)

# %%
contry_and_population_merge.head()
# Out:
#   Country Code                     Region  Year  Polulation
# 0          ABW  Latin America & Caribbean  1960     54211.0
# 1          ABW  Latin America & Caribbean  1961     55438.0
# 2          ABW  Latin America & Caribbean  1962     56225.0
# 3          ABW  Latin America & Caribbean  1963     56695.0
# 4          ABW  Latin America & Caribbean  1964     57032.0

# %% [markdown]
# pd.merge(contry_and_population_merge,life_expectency,how='left',on=['Country Code','Year'])
